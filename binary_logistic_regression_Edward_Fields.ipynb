# %% [markdown]
# # Binary Logistic Regression / Classification
#
# ## Background
# Binary classification is one of the most fundamental and common tasks in machine learning and deep learning.
# At its core, it's a supervised learning problem where the goal is to categorize input data into one of two possible classes or categories.
# Think of it as teaching a machine to make a "yes" or "no" decision.
# Examples of binary classification's applications are:
#
# - Spam Detection: Classifying an email as either 'spam' or 'not spam'.
# - Medical Diagnosis: Determining if a patient has a certain disease.
# - Credit Scoring: Deciding whether a loan applicant is a 'good credit risk' or a 'bad credit risk'.
#
# A sigmoid activated multi-input, single-output linear model is a decent candidate for this job.
# In this practice, you'll train such a model to categorize samples from a toy dataset into two classes.
#
# ## Objectives
# - Train a simple neural network model.
#     - Apply sigmoid activation on a linear model.
#     - Implement binary cross entropy evaluation.
#     - Practice vectorized computing.
# - Assess model's performance using a variety of metrics.
#
#
# ## Exercises:
#
# 1. <font color=#582C83>(5%) Data Pre-Processing</font>
# 2. <font color=#582C83>(10%) Model Creation</font>
# 3. <font color=#582C83>(20%) Model Assessment</font>
# 4. <font color=#582C83>(10%) Gradient of BCE Loss</font>
# 5. <font color=#582C83>(30%) Gradient Descent Model Optimization</font>
# 6. <font color=#582C83>(25%) Classification Metrics</font>

# %% [markdown]
# ## 1. Load and Pre-Process Training Dataset
#
# The dataset,
# $$\mathcal{D} = \{\mathbf{X}, \mathbf{y}\} = \begin{bmatrix} ^{(1)} \mathbf{x} & ^{(1)} y \\ ^{(2)} \mathbf{x} & ^{(2)} y \\ \vdots \\ ^{(M)} \mathbf{x} & ^{(M)} y \end{bmatrix}$$
# consists $M$ samples.
#
# Each sample has $N$ features: $^{(i)} \mathbf{x} = [^{(i)} x_1, ^{(i)} x_2, \dots, ^{(i)} x_N]$ and is labeled as $^{(i)} y \in \{0, 1\}$, where $i \in \{1, 2, ..., M\}$.
#
# In this practice, we make a toy dataset using [scikit-learn](https://scikit-learn.org/stable/index.html)'s [datasets](https://scikit-learn.org/stable/api/sklearn.datasets.html) module.
# The dataset has $M=2048$ samples, and $N=2$ features.

# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt

features_raw, labels_raw = make_blobs(n_samples=2048, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0, random_state=3321)
# Visualize the raw data
plt.scatter(
    features_raw[:, 0], # feature 1 values (x coords)
    features_raw[:, 1], # feature 2 values (y coords)
    s=5*np.ones(labels_raw.size), # marker size all set to 1
    c=labels_raw, # colorized labels: 0:blue, 1:red
    cmap='coolwarm'  # color map
)

# %% [markdown]
# ### <font color=#582C83>(5%) Exercise 1: Data Pre-Processing</font>
# 1. In machine learning, it is prefered to scale features into the same range: $[0, 1]$.
# 2. To avoid dimension mismatch, reshape features and labels array into two dimensions is recommended.

# %%
### START CODING HERE ### (≈ 2 lines of code)
features_train = features_raw / features_raw.max(axis=0)  # Scale features to [0, 1]
labels_train = labels_raw.reshape(-1, 1)
print(features_train[:10])
print(labels_train.shape)  # Reshape labels to be a column vector
### END CODING HERE ### 

# Sanity check
print(f"Samples of pre-processed features:\n {features_train[-4:]}")
print(f"Samples of pre-processed labels:\n {labels_train[-4:]}")  # Print last 4 samples of features and labels
print(f"Shape of pre-processed features:\n {features_train.shape}.")
print(f"Shape of pre-processed labels:\n {labels_train.shape}")  # Print shapes of features and labels   

# Visualize
plt.scatter(
    features_train[:, 0], 
    features_train[:, 1], 
    s=5*np.ones(labels_train.size), 
    c=labels_train, 
    cmap='coolwarm'  # color map
)
# Out:
# [[0.57113148 0.3664097 ]
#  [0.66676081 0.56167142]
#  [0.81536424 0.734261  ]
#  [0.4604502  0.53085877]
#  [0.55895996 0.63040269]
#  [0.46819546 0.72685397]
#  [0.88162396 0.66272621]
#  [0.65828505 0.74446094]
#  [0.46722443 0.6185609 ]
#  [0.58724575 0.59365635]]
# (2048, 1)
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)

# %% [markdown]
# **Expected Outcomes**:
# ```console
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)
# ```

# %% [markdown]
# ## 2. Create a Non-linear Multi-Input Single-Output Model
# Let's create a nonlinear model by applying a sigmoid function to the output of a linear model.
#
# $$\mathbf{\hat{y}} = \sigma (\mathbf{X} \cdot \mathbf{w}^T + \mathbf{b}) = \sigma(\mathbf{Z})$$
#
# The sigmoid function can be represented as,
#
# $$\sigma(\mathbf{Z}) = \frac{1}{1 + e^{-\mathbf{Z}}}$$
#
# The linear part of the model is governed by a parameter vector
# $$\mathbf{w} = [w_1, w_2, ..., w_N]_{(1, N)}$$
#
# and a bias vector
# $$\mathbf{b} = \begin{bmatrix} b \\ b \\ \vdots \\ b \end{bmatrix}_{(M, 1)}$$
#
# And, in this practice $M=2048$ and $N=2$
#
# ### <font color=#582C83>(10%) Exercise 2: Model Creation</font>
# Let's translate math to code.

# %%
def forward(in_features, weights, bias):
    """
    Compute the linear combination of inputs and weights plus bias.
    
    Args:
        in_features (np.ndarray): Input features of shape (M, N).
        weights (np.ndarray): Weights of shape (1, N).
        bias (float): Bias term.  
    Returns:
        predictions: Linear combination result of shape (M, 1).
    """
    ### START CODING HERE ### (≈ 2 lines of code)
    def sigmoid(z):
        return 1 / (1 + np.exp(-z))
    z = np.dot(in_features, weights.T) + bias
    predictions = sigmoid(z)
    return predictions
    ### END CODING HERE ###

# Sanity check
w_dummy = np.array([[1.2, -2.3]])
b_dummy = 1.0
print(f"Samples of dummy prediction:\n {forward(features_train, w_dummy, b_dummy)[-4:]}")  # Print last 4 samples of dummy prediction

# Visualize dummy model decision boundary
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
# Create a meshgrid of points over the feature space
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w_dummy[0, 0] * xx + w_dummy[0, 1] * yy + b_dummy - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
# Out:
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]

# %% [markdown]
# **Expected Outcomes**:
# >
# ```console
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]
# ```

# %% [markdown]
# ## 3. Evaluate Model
# As same as the linear regression, we need to evaluate model performance.
# It is OK to use a Mean Squared Error (MSE) function to compute the model loss.
# It is **recommended** to use a Binary Cross Entropy (BCE) function to assess the model for a binary classification problem.
# Binary Cross Entropy (BCE) is a differentiable metric.
# $$\mathcal{L}(\mathbf{\hat{y}}, \mathbf{y}) = \frac{1}{M} \Sigma [-\mathbf{y} \log \hat{\mathbf{y}} - (1 - \mathbf{y}) \log(1 - \hat{\mathbf{y}})]$$
#
# There are other useful metrics, such as accuracy. But they are not differentiable.
# Let $TP$ be number of true positive predictions, $TN$ be number of true negative predictions, $FP$ be number of false positive predictions, $FN$ be number of false negative predictions.
# The accuracy can be calculated by:
# $$Accuracy = \frac{TP + TN}{TP+FP+TN+FN}$$
#
# ### <font color=#582C83>(20%) Exercise 3: Model Assessment</font>
# 1. Evaluate model loss with BCE.
# 2. Assess model predictions accuracy.

# %%
def bce_loss(predictions, labels):
    """
    Compute the Binary Cross Entropy (BCE) loss.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        loss: BCE loss value (float).
    """
    ### START CODING HERE ### (≈ 1 line)
    loss = -np.mean(labels * np.log(predictions) + (1 - labels) * np.log(1 - predictions))
    return loss
    ### END CODING HERE ###

def accuracy(predictions, labels):
    """
    Compute the accuracy of predictions.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        acc: Accuracy value (float).
    """
    ### START CODING HERE ### (≈ 2 lines)
    predicted_classes = (predictions >= 0.5).astype(int)
    acc = np.mean(predicted_classes == labels)
    return acc
    ### END CODING HERE ###

# Sanity check
preds_dummy = forward(features_train, w_dummy, b_dummy)
print(f"Dummy model BCE loss: {bce_loss(preds_dummy, labels_train)}")
print(f"Dummy model accuracy: {accuracy(preds_dummy, labels_train) * 100}%")
# Out:
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%
# ```

# %% [markdown]
# ## 4. Compute Gradient of Loss
# Compute gradient of the BCE loss:
#
# $$\frac{\partial \mathcal{L}}{\partial \mathbf{w}} = \begin{bmatrix} \frac{\partial \mathcal{L}}{\partial w_1} & \frac{\partial \mathcal{L}}{\partial w_2} & \dots & \frac{\partial \mathcal{L}}{\partial w_N} \end{bmatrix} = \frac{1}{M} (\hat{\mathbf{y}} - \mathbf{y})^T \cdot \mathbf{X}$$
# $$\frac{\partial \mathcal{L}}{\partial b}  = \overline{\hat{\mathbf{y}} - \mathbf{y}} $$
#
# ### <font color=#582C83>(10%) Exercise 4: Gradient of BCE Loss</font>

# %%
def gradient(predictions, labels, in_features):
    """
    Compute the gradient of the BCE loss with respect to weights and bias.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
        in_features (np.ndarray): Input features of shape (M, N).
    Returns:
        dw: Gradient with respect to weights of shape (1, N).
        db: Gradient with respect to bias (float).
    """
    ### START CODING HERE ### (≈ 3 lines of code)
    M = in_features.shape[0]  # Number of samples
    dw = (1 / M) * np.dot((predictions - labels).T, in_features) # Gradient w.r.t. weights
    db = np.mean(predictions - labels)  # Gradient w.r.t. bias
    return dw, db
    ### END CODING HERE ###

# Sanity check
dw_dummy, db_dummy = gradient(preds_dummy, labels_train, features_train)
print(f"Dummy model gradient w.r.t. weights: {dw_dummy}, shape: {dw_dummy.shape}")
print(f"Dummy model gradient w.r.t. bias: {db_dummy}")
# Out:
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689
# ```

# %% [markdown]
# ## 5. Update Model Parameters
#
#
# By tweaking the model parameters along the gradient a small step (learning rate, $\alpha$) iteratively, we expect to bring the BCE loss down to a reasonable scale.
#
# - $\text{Initialize } \mathbf{w} \text{ and } b$
# - $\text{Repeat until converge}$
#     - $\mathbf{w} = \mathbf{w} - \alpha \frac{\partial \mathcal{L}}{\partial \mathbf{w}}$
#     - $b = b - \alpha \frac{\partial \mathcal{L}}{\partial b}$
#
#
#
# ### <font color=#582C83>(30%) Exercise 5: Gradient Descent Model Optimization</font>
# 1. Initialize weights and bias
# 2. Set learning rate and number of iterations
# 3. Repeat following steps:
#
#     1. Make predictions
#     2. Assess model
#     3. Compute gradient of loss
#     4. Update weights and bias
#
# <font color=red>**Note: bring training accuracy over 95% within 10000 iterations**</font>

# %%
# START CODING HERE ### (≈ 10 lines of code)
# Initialize parameters
w = np.zeros((1, 2))  # Initialize weights
b = 0.0  # Initialize bias

# Set hyperparameters
learning_rate = 1.0
num_iters = 10000

# Reserve loss and accuracy storage
losses_train = []
accuracies_train = []

# Training loop
for i in range(num_iters):
    preds_train = forward(features_train, w, b)  # Make predictions
    loss_train = bce_loss(preds_train, labels_train)  # Assess model loss
    acc_train = accuracy(preds_train, labels_train)  # Assess model accuracy
    print(f"Iteration {i+1}/{num_iters}, Loss: {loss_train:.4f}, Accuracy: {acc_train*100:.2f}%")
    losses_train.append(loss_train)
    accuracies_train.append(acc_train)
    dw, db = gradient(preds_train, labels_train, features_train)  # Compute gradient of loss
    w =  w - learning_rate * dw  # Update weights
    b = b - learning_rate * db  # Update bias

### END CODING HERE ###

# Plot training loss and accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses_train, label='Training Loss')
plt.xlabel('Iteration')
plt.ylabel('BCE Loss')
plt.title('Training Loss over Iterations')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(np.array(accuracies_train) * 100, label='Training Accuracy', color='orange')
plt.xlabel('Iteration')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy over Iterations')
plt.legend()
# Out:
# Iteration 1/10000, Loss: 0.6931, Accuracy: 50.00%
# Iteration 2/10000, Loss: 0.6868, Accuracy: 50.00%
# Iteration 3/10000, Loss: 0.6820, Accuracy: 50.00%
# Iteration 4/10000, Loss: 0.6777, Accuracy: 50.00%
# Iteration 5/10000, Loss: 0.6737, Accuracy: 50.00%
# Iteration 6/10000, Loss: 0.6697, Accuracy: 50.00%
# Iteration 7/10000, Loss: 0.6658, Accuracy: 50.20%
# Iteration 8/10000, Loss: 0.6620, Accuracy: 50.73%
# Iteration 9/10000, Loss: 0.6581, Accuracy: 51.76%
# Iteration 10/10000, Loss: 0.6544, Accuracy: 53.91%
# Iteration 11/10000, Loss: 0.6506, Accuracy: 56.10%
# Iteration 12/10000, Loss: 0.6470, Accuracy: 58.74%
# Iteration 13/10000, Loss: 0.6433, Accuracy: 61.28%
# Iteration 14/10000, Loss: 0.6397, Accuracy: 64.75%
# Iteration 15/10000, Loss: 0.6361, Accuracy: 67.87%
# Iteration 16/10000, Loss: 0.6326, Accuracy: 71.19%
# Iteration 17/10000, Loss: 0.6291, Accuracy: 73.34%
# Iteration 18/10000, Loss: 0.6256, Accuracy: 75.29%
# Iteration 19/10000, Loss: 0.6222, Accuracy: 76.86%
# Iteration 20/10000, Loss: 0.6188, Accuracy: 78.76%
# Iteration 21/10000, Loss: 0.6155, Accuracy: 80.13%
# Iteration 22/10000, Loss: 0.6122, Accuracy: 81.49%
# Iteration 23/10000, Loss: 0.6089, Accuracy: 82.32%
# Iteration 24/10000, Loss: 0.6056, Accuracy: 83.40%
# Iteration 25/10000, Loss: 0.6024, Accuracy: 84.47%
# Iteration 26/10000, Loss: 0.5993, Accuracy: 85.64%
# Iteration 27/10000, Loss: 0.5961, Accuracy: 86.38%
# Iteration 28/10000, Loss: 0.5930, Accuracy: 87.45%
# Iteration 29/10000, Loss: 0.5899, Accuracy: 88.04%
# Iteration 30/10000, Loss: 0.5869, Accuracy: 88.57%
# Iteration 31/10000, Loss: 0.5839, Accuracy: 89.26%
# Iteration 32/10000, Loss: 0.5809, Accuracy: 89.84%
# Iteration 33/10000, Loss: 0.5780, Accuracy: 90.28%
# Iteration 34/10000, Loss: 0.5750, Accuracy: 90.58%
# Iteration 35/10000, Loss: 0.5722, Accuracy: 91.02%
# Iteration 36/10000, Loss: 0.5693, Accuracy: 91.36%
# Iteration 37/10000, Loss: 0.5665, Accuracy: 91.75%
# Iteration 38/10000, Loss: 0.5637, Accuracy: 91.99%
# Iteration 39/10000, Loss: 0.5609, Accuracy: 92.14%
# Iteration 40/10000, Loss: 0.5582, Accuracy: 92.33%
# Iteration 41/10000, Loss: 0.5555, Accuracy: 92.53%
# Iteration 42/10000, Loss: 0.5528, Accuracy: 92.77%
# Iteration 43/10000, Loss: 0.5501, Accuracy: 92.82%
# Iteration 44/10000, Loss: 0.5475, Accuracy: 93.12%
# Iteration 45/10000, Loss: 0.5449, Accuracy: 93.41%
# Iteration 46/10000, Loss: 0.5423, Accuracy: 93.55%
# Iteration 47/10000, Loss: 0.5398, Accuracy: 93.90%
# Iteration 48/10000, Loss: 0.5372, Accuracy: 93.99%
# Iteration 49/10000, Loss: 0.5347, Accuracy: 94.14%
# Iteration 50/10000, Loss: 0.5323, Accuracy: 94.14%
# Iteration 51/10000, Loss: 0.5298, Accuracy: 94.29%
# Iteration 52/10000, Loss: 0.5274, Accuracy: 94.43%
# Iteration 53/10000, Loss: 0.5250, Accuracy: 94.43%
# Iteration 54/10000, Loss: 0.5226, Accuracy: 94.48%
# Iteration 55/10000, Loss: 0.5203, Accuracy: 94.58%
# Iteration 56/10000, Loss: 0.5179, Accuracy: 94.53%
# Iteration 57/10000, Loss: 0.5156, Accuracy: 94.58%
# Iteration 58/10000, Loss: 0.5134, Accuracy: 94.73%
# Iteration 59/10000, Loss: 0.5111, Accuracy: 94.73%
# Iteration 60/10000, Loss: 0.5089, Accuracy: 94.73%
# Iteration 61/10000, Loss: 0.5066, Accuracy: 94.73%
# Iteration 62/10000, Loss: 0.5045, Accuracy: 94.87%
# Iteration 63/10000, Loss: 0.5023, Accuracy: 94.82%
# Iteration 64/10000, Loss: 0.5001, Accuracy: 94.87%
# Iteration 65/10000, Loss: 0.4980, Accuracy: 94.97%
# Iteration 66/10000, Loss: 0.4959, Accuracy: 94.97%
# Iteration 67/10000, Loss: 0.4938, Accuracy: 95.07%
# Iteration 68/10000, Loss: 0.4917, Accuracy: 95.17%
# Iteration 69/10000, Loss: 0.4897, Accuracy: 95.17%
# Iteration 70/10000, Loss: 0.4877, Accuracy: 95.17%
# Iteration 71/10000, Loss: 0.4856, Accuracy: 95.17%
# Iteration 72/10000, Loss: 0.4836, Accuracy: 95.17%
# Iteration 73/10000, Loss: 0.4817, Accuracy: 95.21%
# Iteration 74/10000, Loss: 0.4797, Accuracy: 95.31%
# Iteration 75/10000, Loss: 0.4778, Accuracy: 95.36%
# Iteration 76/10000, Loss: 0.4759, Accuracy: 95.36%
# Iteration 77/10000, Loss: 0.4740, Accuracy: 95.36%
# Iteration 78/10000, Loss: 0.4721, Accuracy: 95.36%
# Iteration 79/10000, Loss: 0.4702, Accuracy: 95.36%
# Iteration 80/10000, Loss: 0.4684, Accuracy: 95.41%
# Iteration 81/10000, Loss: 0.4665, Accuracy: 95.41%
# Iteration 82/10000, Loss: 0.4647, Accuracy: 95.46%
# Iteration 83/10000, Loss: 0.4629, Accuracy: 95.41%
# Iteration 84/10000, Loss: 0.4612, Accuracy: 95.51%
# Iteration 85/10000, Loss: 0.4594, Accuracy: 95.56%
# Iteration 86/10000, Loss: 0.4576, Accuracy: 95.51%
# Iteration 87/10000, Loss: 0.4559, Accuracy: 95.51%
# Iteration 88/10000, Loss: 0.4542, Accuracy: 95.56%
# Iteration 89/10000, Loss: 0.4525, Accuracy: 95.56%
# Iteration 90/10000, Loss: 0.4508, Accuracy: 95.61%
# Iteration 91/10000, Loss: 0.4491, Accuracy: 95.61%
# Iteration 92/10000, Loss: 0.4475, Accuracy: 95.56%
# Iteration 93/10000, Loss: 0.4458, Accuracy: 95.51%
# Iteration 94/10000, Loss: 0.4442, Accuracy: 95.51%
# Iteration 95/10000, Loss: 0.4426, Accuracy: 95.51%
# Iteration 96/10000, Loss: 0.4410, Accuracy: 95.51%
# Iteration 97/10000, Loss: 0.4394, Accuracy: 95.51%
# Iteration 98/10000, Loss: 0.4379, Accuracy: 95.56%
# Iteration 99/10000, Loss: 0.4363, Accuracy: 95.56%
# Iteration 100/10000, Loss: 0.4348, Accuracy: 95.56%
# Iteration 101/10000, Loss: 0.4332, Accuracy: 95.51%
# Iteration 102/10000, Loss: 0.4317, Accuracy: 95.51%
# Iteration 103/10000, Loss: 0.4302, Accuracy: 95.51%
# Iteration 104/10000, Loss: 0.4287, Accuracy: 95.51%
# Iteration 105/10000, Loss: 0.4272, Accuracy: 95.56%
# Iteration 106/10000, Loss: 0.4258, Accuracy: 95.56%
# Iteration 107/10000, Loss: 0.4243, Accuracy: 95.51%
# Iteration 108/10000, Loss: 0.4229, Accuracy: 95.51%
# Iteration 109/10000, Loss: 0.4215, Accuracy: 95.56%
# Iteration 110/10000, Loss: 0.4200, Accuracy: 95.56%
# Iteration 111/10000, Loss: 0.4186, Accuracy: 95.56%
# Iteration 112/10000, Loss: 0.4172, Accuracy: 95.56%
# Iteration 113/10000, Loss: 0.4159, Accuracy: 95.56%
# Iteration 114/10000, Loss: 0.4145, Accuracy: 95.65%
# Iteration 115/10000, Loss: 0.4131, Accuracy: 95.65%
# Iteration 116/10000, Loss: 0.4118, Accuracy: 95.70%
# Iteration 117/10000, Loss: 0.4105, Accuracy: 95.70%
# Iteration 118/10000, Loss: 0.4091, Accuracy: 95.70%
# Iteration 119/10000, Loss: 0.4078, Accuracy: 95.75%
# Iteration 120/10000, Loss: 0.4065, Accuracy: 95.75%
# Iteration 121/10000, Loss: 0.4052, Accuracy: 95.70%
# Iteration 122/10000, Loss: 0.4039, Accuracy: 95.75%
# Iteration 123/10000, Loss: 0.4027, Accuracy: 95.75%
# Iteration 124/10000, Loss: 0.4014, Accuracy: 95.70%
# Iteration 125/10000, Loss: 0.4002, Accuracy: 95.70%
# Iteration 126/10000, Loss: 0.3989, Accuracy: 95.70%
# Iteration 127/10000, Loss: 0.3977, Accuracy: 95.70%
# Iteration 128/10000, Loss: 0.3965, Accuracy: 95.70%
# Iteration 129/10000, Loss: 0.3953, Accuracy: 95.75%
# Iteration 130/10000, Loss: 0.3940, Accuracy: 95.75%
# Iteration 131/10000, Loss: 0.3929, Accuracy: 95.75%
# Iteration 132/10000, Loss: 0.3917, Accuracy: 95.75%
# Iteration 133/10000, Loss: 0.3905, Accuracy: 95.75%
# Iteration 134/10000, Loss: 0.3893, Accuracy: 95.75%
# Iteration 135/10000, Loss: 0.3882, Accuracy: 95.75%
# Iteration 136/10000, Loss: 0.3870, Accuracy: 95.75%
# Iteration 137/10000, Loss: 0.3859, Accuracy: 95.75%
# Iteration 138/10000, Loss: 0.3848, Accuracy: 95.75%
# Iteration 139/10000, Loss: 0.3836, Accuracy: 95.75%
# Iteration 140/10000, Loss: 0.3825, Accuracy: 95.75%
# Iteration 141/10000, Loss: 0.3814, Accuracy: 95.80%
# Iteration 142/10000, Loss: 0.3803, Accuracy: 95.80%
# Iteration 143/10000, Loss: 0.3792, Accuracy: 95.80%
# Iteration 144/10000, Loss: 0.3782, Accuracy: 95.80%
# Iteration 145/10000, Loss: 0.3771, Accuracy: 95.80%
# Iteration 146/10000, Loss: 0.3760, Accuracy: 95.85%
# Iteration 147/10000, Loss: 0.3750, Accuracy: 95.85%
# Iteration 148/10000, Loss: 0.3739, Accuracy: 95.85%
# Iteration 149/10000, Loss: 0.3729, Accuracy: 95.85%
# Iteration 150/10000, Loss: 0.3719, Accuracy: 95.90%
# Iteration 151/10000, Loss: 0.3708, Accuracy: 95.90%
# Iteration 152/10000, Loss: 0.3698, Accuracy: 95.90%
# Iteration 153/10000, Loss: 0.3688, Accuracy: 95.90%
# Iteration 154/10000, Loss: 0.3678, Accuracy: 95.90%
# Iteration 155/10000, Loss: 0.3668, Accuracy: 95.90%
# Iteration 156/10000, Loss: 0.3658, Accuracy: 95.95%
# Iteration 157/10000, Loss: 0.3648, Accuracy: 95.95%
# Iteration 158/10000, Loss: 0.3639, Accuracy: 95.95%
# Iteration 159/10000, Loss: 0.3629, Accuracy: 95.95%
# Iteration 160/10000, Loss: 0.3619, Accuracy: 95.95%
# Iteration 161/10000, Loss: 0.3610, Accuracy: 95.95%
# Iteration 162/10000, Loss: 0.3600, Accuracy: 95.95%
# Iteration 163/10000, Loss: 0.3591, Accuracy: 95.95%
# Iteration 164/10000, Loss: 0.3582, Accuracy: 95.95%
# Iteration 165/10000, Loss: 0.3572, Accuracy: 95.95%
# Iteration 166/10000, Loss: 0.3563, Accuracy: 95.95%
# Iteration 167/10000, Loss: 0.3554, Accuracy: 95.95%
# Iteration 168/10000, Loss: 0.3545, Accuracy: 95.95%
# Iteration 169/10000, Loss: 0.3536, Accuracy: 95.95%
# Iteration 170/10000, Loss: 0.3527, Accuracy: 95.95%
# Iteration 171/10000, Loss: 0.3518, Accuracy: 95.95%
# Iteration 172/10000, Loss: 0.3509, Accuracy: 95.95%
# Iteration 173/10000, Loss: 0.3501, Accuracy: 95.95%
# Iteration 174/10000, Loss: 0.3492, Accuracy: 95.95%
# Iteration 175/10000, Loss: 0.3483, Accuracy: 95.95%
# Iteration 176/10000, Loss: 0.3475, Accuracy: 95.95%
# Iteration 177/10000, Loss: 0.3466, Accuracy: 95.95%
# Iteration 178/10000, Loss: 0.3458, Accuracy: 95.95%
# Iteration 179/10000, Loss: 0.3449, Accuracy: 95.95%
# Iteration 180/10000, Loss: 0.3441, Accuracy: 95.95%
# Iteration 181/10000, Loss: 0.3433, Accuracy: 95.95%
# Iteration 182/10000, Loss: 0.3424, Accuracy: 95.95%
# Iteration 183/10000, Loss: 0.3416, Accuracy: 95.95%
# Iteration 184/10000, Loss: 0.3408, Accuracy: 95.95%
# Iteration 185/10000, Loss: 0.3400, Accuracy: 95.90%
# Iteration 186/10000, Loss: 0.3392, Accuracy: 95.90%
# Iteration 187/10000, Loss: 0.3384, Accuracy: 95.90%
# Iteration 188/10000, Loss: 0.3376, Accuracy: 95.90%
# Iteration 189/10000, Loss: 0.3368, Accuracy: 95.90%
# Iteration 190/10000, Loss: 0.3361, Accuracy: 95.90%
# Iteration 191/10000, Loss: 0.3353, Accuracy: 95.90%
# Iteration 192/10000, Loss: 0.3345, Accuracy: 95.90%
# Iteration 193/10000, Loss: 0.3337, Accuracy: 95.90%
# Iteration 194/10000, Loss: 0.3330, Accuracy: 95.85%
# Iteration 195/10000, Loss: 0.3322, Accuracy: 95.85%
# Iteration 196/10000, Loss: 0.3315, Accuracy: 95.85%
# Iteration 197/10000, Loss: 0.3307, Accuracy: 95.85%
# Iteration 198/10000, Loss: 0.3300, Accuracy: 95.85%
# Iteration 199/10000, Loss: 0.3292, Accuracy: 95.85%
# Iteration 200/10000, Loss: 0.3285, Accuracy: 95.85%
# Iteration 201/10000, Loss: 0.3278, Accuracy: 95.85%
# Iteration 202/10000, Loss: 0.3271, Accuracy: 95.90%
# Iteration 203/10000, Loss: 0.3263, Accuracy: 95.90%
# Iteration 204/10000, Loss: 0.3256, Accuracy: 95.90%
# Iteration 205/10000, Loss: 0.3249, Accuracy: 95.90%
# Iteration 206/10000, Loss: 0.3242, Accuracy: 95.85%
# Iteration 207/10000, Loss: 0.3235, Accuracy: 95.85%
# Iteration 208/10000, Loss: 0.3228, Accuracy: 95.85%
# Iteration 209/10000, Loss: 0.3221, Accuracy: 95.85%
# Iteration 210/10000, Loss: 0.3214, Accuracy: 95.80%
# Iteration 211/10000, Loss: 0.3207, Accuracy: 95.80%
# Iteration 212/10000, Loss: 0.3201, Accuracy: 95.80%
# Iteration 213/10000, Loss: 0.3194, Accuracy: 95.75%
# Iteration 214/10000, Loss: 0.3187, Accuracy: 95.75%
# Iteration 215/10000, Loss: 0.3181, Accuracy: 95.75%
# Iteration 216/10000, Loss: 0.3174, Accuracy: 95.75%
# Iteration 217/10000, Loss: 0.3167, Accuracy: 95.75%
# Iteration 218/10000, Loss: 0.3161, Accuracy: 95.75%
# Iteration 219/10000, Loss: 0.3154, Accuracy: 95.75%
# Iteration 220/10000, Loss: 0.3148, Accuracy: 95.75%
# Iteration 221/10000, Loss: 0.3141, Accuracy: 95.75%
# Iteration 222/10000, Loss: 0.3135, Accuracy: 95.75%
# Iteration 223/10000, Loss: 0.3129, Accuracy: 95.75%
# Iteration 224/10000, Loss: 0.3122, Accuracy: 95.75%
# Iteration 225/10000, Loss: 0.3116, Accuracy: 95.80%
# Iteration 226/10000, Loss: 0.3110, Accuracy: 95.80%
# Iteration 227/10000, Loss: 0.3103, Accuracy: 95.80%
# Iteration 228/10000, Loss: 0.3097, Accuracy: 95.85%
# Iteration 229/10000, Loss: 0.3091, Accuracy: 95.85%
# Iteration 230/10000, Loss: 0.3085, Accuracy: 95.85%
# Iteration 231/10000, Loss: 0.3079, Accuracy: 95.85%
# Iteration 232/10000, Loss: 0.3073, Accuracy: 95.85%
# Iteration 233/10000, Loss: 0.3067, Accuracy: 95.85%
# Iteration 234/10000, Loss: 0.3061, Accuracy: 95.85%
# Iteration 235/10000, Loss: 0.3055, Accuracy: 95.85%
# Iteration 236/10000, Loss: 0.3049, Accuracy: 95.85%
# Iteration 237/10000, Loss: 0.3043, Accuracy: 95.85%
# Iteration 238/10000, Loss: 0.3037, Accuracy: 95.85%
# Iteration 239/10000, Loss: 0.3032, Accuracy: 95.85%
# Iteration 240/10000, Loss: 0.3026, Accuracy: 95.85%
# Iteration 241/10000, Loss: 0.3020, Accuracy: 95.85%
# Iteration 242/10000, Loss: 0.3014, Accuracy: 95.85%
# Iteration 243/10000, Loss: 0.3009, Accuracy: 95.90%
# Iteration 244/10000, Loss: 0.3003, Accuracy: 95.90%
# Iteration 245/10000, Loss: 0.2998, Accuracy: 95.90%
# Iteration 246/10000, Loss: 0.2992, Accuracy: 95.90%
# Iteration 247/10000, Loss: 0.2986, Accuracy: 95.90%
# Iteration 248/10000, Loss: 0.2981, Accuracy: 95.90%
# Iteration 249/10000, Loss: 0.2975, Accuracy: 95.85%
# Iteration 250/10000, Loss: 0.2970, Accuracy: 95.85%
# Iteration 251/10000, Loss: 0.2965, Accuracy: 95.85%
# Iteration 252/10000, Loss: 0.2959, Accuracy: 95.85%
# Iteration 253/10000, Loss: 0.2954, Accuracy: 95.85%
# Iteration 254/10000, Loss: 0.2948, Accuracy: 95.85%
# Iteration 255/10000, Loss: 0.2943, Accuracy: 95.85%
# Iteration 256/10000, Loss: 0.2938, Accuracy: 95.85%
# Iteration 257/10000, Loss: 0.2933, Accuracy: 95.85%
# Iteration 258/10000, Loss: 0.2927, Accuracy: 95.85%
# Iteration 259/10000, Loss: 0.2922, Accuracy: 95.85%
# Iteration 260/10000, Loss: 0.2917, Accuracy: 95.85%
# Iteration 261/10000, Loss: 0.2912, Accuracy: 95.85%
# Iteration 262/10000, Loss: 0.2907, Accuracy: 95.85%
# Iteration 263/10000, Loss: 0.2902, Accuracy: 95.85%
# Iteration 264/10000, Loss: 0.2897, Accuracy: 95.85%
# Iteration 265/10000, Loss: 0.2892, Accuracy: 95.85%
# Iteration 266/10000, Loss: 0.2887, Accuracy: 95.85%
# Iteration 267/10000, Loss: 0.2882, Accuracy: 95.90%
# Iteration 268/10000, Loss: 0.2877, Accuracy: 95.90%
# Iteration 269/10000, Loss: 0.2872, Accuracy: 95.90%
# Iteration 270/10000, Loss: 0.2867, Accuracy: 95.90%
# Iteration 271/10000, Loss: 0.2862, Accuracy: 95.90%
# Iteration 272/10000, Loss: 0.2857, Accuracy: 95.90%
# Iteration 273/10000, Loss: 0.2852, Accuracy: 95.90%
# Iteration 274/10000, Loss: 0.2847, Accuracy: 95.90%
# Iteration 275/10000, Loss: 0.2843, Accuracy: 95.90%
# Iteration 276/10000, Loss: 0.2838, Accuracy: 95.90%
# Iteration 277/10000, Loss: 0.2833, Accuracy: 95.90%
# Iteration 278/10000, Loss: 0.2829, Accuracy: 95.90%
# Iteration 279/10000, Loss: 0.2824, Accuracy: 95.90%
# Iteration 280/10000, Loss: 0.2819, Accuracy: 95.90%
# Iteration 281/10000, Loss: 0.2815, Accuracy: 95.90%
# Iteration 282/10000, Loss: 0.2810, Accuracy: 95.90%
# Iteration 283/10000, Loss: 0.2805, Accuracy: 95.90%
# Iteration 284/10000, Loss: 0.2801, Accuracy: 95.90%
# Iteration 285/10000, Loss: 0.2796, Accuracy: 95.90%
# Iteration 286/10000, Loss: 0.2792, Accuracy: 95.90%
# Iteration 287/10000, Loss: 0.2787, Accuracy: 95.95%
# Iteration 288/10000, Loss: 0.2783, Accuracy: 95.95%
# Iteration 289/10000, Loss: 0.2778, Accuracy: 95.95%
# Iteration 290/10000, Loss: 0.2774, Accuracy: 95.95%
# Iteration 291/10000, Loss: 0.2770, Accuracy: 95.95%
# Iteration 292/10000, Loss: 0.2765, Accuracy: 95.95%
# Iteration 293/10000, Loss: 0.2761, Accuracy: 95.95%
# Iteration 294/10000, Loss: 0.2756, Accuracy: 95.95%
# Iteration 295/10000, Loss: 0.2752, Accuracy: 95.95%
# Iteration 296/10000, Loss: 0.2748, Accuracy: 95.95%
# Iteration 297/10000, Loss: 0.2744, Accuracy: 95.95%
# Iteration 298/10000, Loss: 0.2739, Accuracy: 95.95%
# Iteration 299/10000, Loss: 0.2735, Accuracy: 95.95%
# Iteration 300/10000, Loss: 0.2731, Accuracy: 95.95%
# Iteration 301/10000, Loss: 0.2727, Accuracy: 95.95%
# Iteration 302/10000, Loss: 0.2722, Accuracy: 95.95%
# Iteration 303/10000, Loss: 0.2718, Accuracy: 95.95%
# Iteration 304/10000, Loss: 0.2714, Accuracy: 95.95%
# Iteration 305/10000, Loss: 0.2710, Accuracy: 95.95%
# Iteration 306/10000, Loss: 0.2706, Accuracy: 95.95%
# Iteration 307/10000, Loss: 0.2702, Accuracy: 95.95%
# Iteration 308/10000, Loss: 0.2698, Accuracy: 95.95%
# Iteration 309/10000, Loss: 0.2694, Accuracy: 95.95%
# Iteration 310/10000, Loss: 0.2690, Accuracy: 95.95%
# Iteration 311/10000, Loss: 0.2686, Accuracy: 95.95%
# Iteration 312/10000, Loss: 0.2682, Accuracy: 95.95%
# Iteration 313/10000, Loss: 0.2678, Accuracy: 95.95%
# Iteration 314/10000, Loss: 0.2674, Accuracy: 95.95%
# Iteration 315/10000, Loss: 0.2670, Accuracy: 95.95%
# Iteration 316/10000, Loss: 0.2666, Accuracy: 95.95%
# Iteration 317/10000, Loss: 0.2662, Accuracy: 95.90%
# Iteration 318/10000, Loss: 0.2658, Accuracy: 95.90%
# Iteration 319/10000, Loss: 0.2654, Accuracy: 95.90%
# Iteration 320/10000, Loss: 0.2651, Accuracy: 95.90%
# Iteration 321/10000, Loss: 0.2647, Accuracy: 95.90%
# Iteration 322/10000, Loss: 0.2643, Accuracy: 95.90%
# Iteration 323/10000, Loss: 0.2639, Accuracy: 95.90%
# Iteration 324/10000, Loss: 0.2635, Accuracy: 95.90%
# Iteration 325/10000, Loss: 0.2632, Accuracy: 95.90%
# Iteration 326/10000, Loss: 0.2628, Accuracy: 95.90%
# Iteration 327/10000, Loss: 0.2624, Accuracy: 95.90%
# Iteration 328/10000, Loss: 0.2621, Accuracy: 95.90%
# Iteration 329/10000, Loss: 0.2617, Accuracy: 95.90%
# Iteration 330/10000, Loss: 0.2613, Accuracy: 95.90%
# Iteration 331/10000, Loss: 0.2610, Accuracy: 95.90%
# Iteration 332/10000, Loss: 0.2606, Accuracy: 95.90%
# Iteration 333/10000, Loss: 0.2602, Accuracy: 95.90%
# Iteration 334/10000, Loss: 0.2599, Accuracy: 95.90%
# Iteration 335/10000, Loss: 0.2595, Accuracy: 95.95%
# Iteration 336/10000, Loss: 0.2592, Accuracy: 95.95%
# Iteration 337/10000, Loss: 0.2588, Accuracy: 95.95%
# Iteration 338/10000, Loss: 0.2585, Accuracy: 95.95%
# Iteration 339/10000, Loss: 0.2581, Accuracy: 95.95%
# Iteration 340/10000, Loss: 0.2577, Accuracy: 95.95%
# Iteration 341/10000, Loss: 0.2574, Accuracy: 95.95%
# Iteration 342/10000, Loss: 0.2571, Accuracy: 95.95%
# Iteration 343/10000, Loss: 0.2567, Accuracy: 95.95%
# Iteration 344/10000, Loss: 0.2564, Accuracy: 95.95%
# Iteration 345/10000, Loss: 0.2560, Accuracy: 96.00%
# Iteration 346/10000, Loss: 0.2557, Accuracy: 96.00%
# Iteration 347/10000, Loss: 0.2553, Accuracy: 96.00%
# Iteration 348/10000, Loss: 0.2550, Accuracy: 96.00%
# Iteration 349/10000, Loss: 0.2547, Accuracy: 96.00%
# Iteration 350/10000, Loss: 0.2543, Accuracy: 96.00%
# Iteration 351/10000, Loss: 0.2540, Accuracy: 96.00%
# Iteration 352/10000, Loss: 0.2537, Accuracy: 96.00%
# Iteration 353/10000, Loss: 0.2533, Accuracy: 96.00%
# Iteration 354/10000, Loss: 0.2530, Accuracy: 96.00%
# Iteration 355/10000, Loss: 0.2527, Accuracy: 96.00%
# Iteration 356/10000, Loss: 0.2523, Accuracy: 96.00%
# Iteration 357/10000, Loss: 0.2520, Accuracy: 96.00%
# Iteration 358/10000, Loss: 0.2517, Accuracy: 96.00%
# Iteration 359/10000, Loss: 0.2514, Accuracy: 96.00%
# Iteration 360/10000, Loss: 0.2511, Accuracy: 96.00%
# Iteration 361/10000, Loss: 0.2507, Accuracy: 96.00%
# Iteration 362/10000, Loss: 0.2504, Accuracy: 96.00%
# Iteration 363/10000, Loss: 0.2501, Accuracy: 96.00%
# Iteration 364/10000, Loss: 0.2498, Accuracy: 96.00%
# Iteration 365/10000, Loss: 0.2495, Accuracy: 96.00%
# Iteration 366/10000, Loss: 0.2491, Accuracy: 96.00%
# Iteration 367/10000, Loss: 0.2488, Accuracy: 96.00%
# Iteration 368/10000, Loss: 0.2485, Accuracy: 96.00%
# Iteration 369/10000, Loss: 0.2482, Accuracy: 96.04%
# Iteration 370/10000, Loss: 0.2479, Accuracy: 96.04%
# Iteration 371/10000, Loss: 0.2476, Accuracy: 96.04%
# Iteration 372/10000, Loss: 0.2473, Accuracy: 96.04%
# Iteration 373/10000, Loss: 0.2470, Accuracy: 96.04%
# Iteration 374/10000, Loss: 0.2467, Accuracy: 96.04%
# Iteration 375/10000, Loss: 0.2464, Accuracy: 96.04%
# Iteration 376/10000, Loss: 0.2461, Accuracy: 96.04%
# Iteration 377/10000, Loss: 0.2458, Accuracy: 96.04%
# Iteration 378/10000, Loss: 0.2455, Accuracy: 96.04%
# Iteration 379/10000, Loss: 0.2452, Accuracy: 96.04%
# Iteration 380/10000, Loss: 0.2449, Accuracy: 96.04%
# Iteration 381/10000, Loss: 0.2446, Accuracy: 96.04%
# Iteration 382/10000, Loss: 0.2443, Accuracy: 96.04%
# Iteration 383/10000, Loss: 0.2440, Accuracy: 96.04%
# Iteration 384/10000, Loss: 0.2437, Accuracy: 96.04%
# Iteration 385/10000, Loss: 0.2434, Accuracy: 96.04%
# Iteration 386/10000, Loss: 0.2431, Accuracy: 96.04%
# Iteration 387/10000, Loss: 0.2429, Accuracy: 96.04%
# Iteration 388/10000, Loss: 0.2426, Accuracy: 96.04%
# Iteration 389/10000, Loss: 0.2423, Accuracy: 96.04%
# Iteration 390/10000, Loss: 0.2420, Accuracy: 96.04%
# Iteration 391/10000, Loss: 0.2417, Accuracy: 96.04%
# Iteration 392/10000, Loss: 0.2414, Accuracy: 96.04%
# Iteration 393/10000, Loss: 0.2412, Accuracy: 96.04%
# Iteration 394/10000, Loss: 0.2409, Accuracy: 96.04%
# Iteration 395/10000, Loss: 0.2406, Accuracy: 96.04%
# Iteration 396/10000, Loss: 0.2403, Accuracy: 96.04%
# Iteration 397/10000, Loss: 0.2400, Accuracy: 96.04%
# Iteration 398/10000, Loss: 0.2398, Accuracy: 96.04%
# Iteration 399/10000, Loss: 0.2395, Accuracy: 96.04%
# Iteration 400/10000, Loss: 0.2392, Accuracy: 96.04%
# Iteration 401/10000, Loss: 0.2389, Accuracy: 96.04%
# Iteration 402/10000, Loss: 0.2387, Accuracy: 96.04%
# Iteration 403/10000, Loss: 0.2384, Accuracy: 96.04%
# Iteration 404/10000, Loss: 0.2381, Accuracy: 96.04%
# Iteration 405/10000, Loss: 0.2379, Accuracy: 96.04%
# Iteration 406/10000, Loss: 0.2376, Accuracy: 96.04%
# Iteration 407/10000, Loss: 0.2373, Accuracy: 96.04%
# Iteration 408/10000, Loss: 0.2371, Accuracy: 96.04%
# Iteration 409/10000, Loss: 0.2368, Accuracy: 96.04%
# Iteration 410/10000, Loss: 0.2365, Accuracy: 96.04%
# Iteration 411/10000, Loss: 0.2363, Accuracy: 96.04%
# Iteration 412/10000, Loss: 0.2360, Accuracy: 96.04%
# Iteration 413/10000, Loss: 0.2358, Accuracy: 96.04%
# Iteration 414/10000, Loss: 0.2355, Accuracy: 96.04%
# Iteration 415/10000, Loss: 0.2352, Accuracy: 96.04%
# Iteration 416/10000, Loss: 0.2350, Accuracy: 96.04%
# Iteration 417/10000, Loss: 0.2347, Accuracy: 96.04%
# Iteration 418/10000, Loss: 0.2345, Accuracy: 96.04%
# Iteration 419/10000, Loss: 0.2342, Accuracy: 96.04%
# Iteration 420/10000, Loss: 0.2340, Accuracy: 96.04%
# Iteration 421/10000, Loss: 0.2337, Accuracy: 96.04%
# Iteration 422/10000, Loss: 0.2335, Accuracy: 96.04%
# Iteration 423/10000, Loss: 0.2332, Accuracy: 96.04%
# Iteration 424/10000, Loss: 0.2330, Accuracy: 96.04%
# Iteration 425/10000, Loss: 0.2327, Accuracy: 96.04%
# Iteration 426/10000, Loss: 0.2325, Accuracy: 96.04%
# Iteration 427/10000, Loss: 0.2322, Accuracy: 96.04%
# Iteration 428/10000, Loss: 0.2320, Accuracy: 96.04%
# Iteration 429/10000, Loss: 0.2317, Accuracy: 96.04%
# Iteration 430/10000, Loss: 0.2315, Accuracy: 96.04%
# Iteration 431/10000, Loss: 0.2312, Accuracy: 96.04%
# Iteration 432/10000, Loss: 0.2310, Accuracy: 96.04%
# Iteration 433/10000, Loss: 0.2307, Accuracy: 96.04%
# Iteration 434/10000, Loss: 0.2305, Accuracy: 96.04%
# Iteration 435/10000, Loss: 0.2303, Accuracy: 96.04%
# Iteration 436/10000, Loss: 0.2300, Accuracy: 96.04%
# Iteration 437/10000, Loss: 0.2298, Accuracy: 96.04%
# Iteration 438/10000, Loss: 0.2295, Accuracy: 96.04%
# Iteration 439/10000, Loss: 0.2293, Accuracy: 96.04%
# Iteration 440/10000, Loss: 0.2291, Accuracy: 96.04%
# Iteration 441/10000, Loss: 0.2288, Accuracy: 96.04%
# Iteration 442/10000, Loss: 0.2286, Accuracy: 96.04%
# Iteration 443/10000, Loss: 0.2284, Accuracy: 96.04%
# Iteration 444/10000, Loss: 0.2281, Accuracy: 96.04%
# Iteration 445/10000, Loss: 0.2279, Accuracy: 96.04%
# Iteration 446/10000, Loss: 0.2277, Accuracy: 96.04%
# Iteration 447/10000, Loss: 0.2275, Accuracy: 96.04%
# Iteration 448/10000, Loss: 0.2272, Accuracy: 96.04%
# Iteration 449/10000, Loss: 0.2270, Accuracy: 96.04%
# Iteration 450/10000, Loss: 0.2268, Accuracy: 96.04%
# Iteration 451/10000, Loss: 0.2265, Accuracy: 96.04%
# Iteration 452/10000, Loss: 0.2263, Accuracy: 96.04%
# Iteration 453/10000, Loss: 0.2261, Accuracy: 96.04%
# Iteration 454/10000, Loss: 0.2259, Accuracy: 96.04%
# Iteration 455/10000, Loss: 0.2256, Accuracy: 96.04%
# Iteration 456/10000, Loss: 0.2254, Accuracy: 96.04%
# Iteration 457/10000, Loss: 0.2252, Accuracy: 96.04%
# Iteration 458/10000, Loss: 0.2250, Accuracy: 96.04%
# Iteration 459/10000, Loss: 0.2248, Accuracy: 96.04%
# Iteration 460/10000, Loss: 0.2245, Accuracy: 96.04%
# Iteration 461/10000, Loss: 0.2243, Accuracy: 96.04%
# Iteration 462/10000, Loss: 0.2241, Accuracy: 96.04%
# Iteration 463/10000, Loss: 0.2239, Accuracy: 96.04%
# Iteration 464/10000, Loss: 0.2237, Accuracy: 96.04%
# Iteration 465/10000, Loss: 0.2234, Accuracy: 96.04%
# Iteration 466/10000, Loss: 0.2232, Accuracy: 96.04%
# Iteration 467/10000, Loss: 0.2230, Accuracy: 96.04%
# Iteration 468/10000, Loss: 0.2228, Accuracy: 96.04%
# Iteration 469/10000, Loss: 0.2226, Accuracy: 96.04%
# Iteration 470/10000, Loss: 0.2224, Accuracy: 96.04%
# Iteration 471/10000, Loss: 0.2222, Accuracy: 96.04%
# Iteration 472/10000, Loss: 0.2220, Accuracy: 96.09%
# Iteration 473/10000, Loss: 0.2217, Accuracy: 96.09%
# Iteration 474/10000, Loss: 0.2215, Accuracy: 96.09%
# Iteration 475/10000, Loss: 0.2213, Accuracy: 96.09%
# Iteration 476/10000, Loss: 0.2211, Accuracy: 96.09%
# Iteration 477/10000, Loss: 0.2209, Accuracy: 96.09%
# Iteration 478/10000, Loss: 0.2207, Accuracy: 96.09%
# Iteration 479/10000, Loss: 0.2205, Accuracy: 96.09%
# Iteration 480/10000, Loss: 0.2203, Accuracy: 96.09%
# Iteration 481/10000, Loss: 0.2201, Accuracy: 96.09%
# Iteration 482/10000, Loss: 0.2199, Accuracy: 96.09%
# Iteration 483/10000, Loss: 0.2197, Accuracy: 96.09%
# Iteration 484/10000, Loss: 0.2195, Accuracy: 96.09%
# Iteration 485/10000, Loss: 0.2193, Accuracy: 96.14%
# Iteration 486/10000, Loss: 0.2191, Accuracy: 96.14%
# Iteration 487/10000, Loss: 0.2189, Accuracy: 96.14%
# Iteration 488/10000, Loss: 0.2187, Accuracy: 96.14%
# Iteration 489/10000, Loss: 0.2185, Accuracy: 96.14%
# Iteration 490/10000, Loss: 0.2183, Accuracy: 96.14%
# Iteration 491/10000, Loss: 0.2181, Accuracy: 96.14%
# Iteration 492/10000, Loss: 0.2179, Accuracy: 96.14%
# Iteration 493/10000, Loss: 0.2177, Accuracy: 96.14%
# Iteration 494/10000, Loss: 0.2175, Accuracy: 96.14%
# Iteration 495/10000, Loss: 0.2173, Accuracy: 96.14%
# Iteration 496/10000, Loss: 0.2171, Accuracy: 96.14%
# Iteration 497/10000, Loss: 0.2169, Accuracy: 96.14%
# Iteration 498/10000, Loss: 0.2167, Accuracy: 96.14%
# Iteration 499/10000, Loss: 0.2165, Accuracy: 96.14%
# Iteration 500/10000, Loss: 0.2163, Accuracy: 96.14%
# Iteration 501/10000, Loss: 0.2161, Accuracy: 96.14%
# Iteration 502/10000, Loss: 0.2159, Accuracy: 96.14%
# Iteration 503/10000, Loss: 0.2158, Accuracy: 96.14%
# Iteration 504/10000, Loss: 0.2156, Accuracy: 96.14%
# Iteration 505/10000, Loss: 0.2154, Accuracy: 96.14%
# Iteration 506/10000, Loss: 0.2152, Accuracy: 96.14%
# Iteration 507/10000, Loss: 0.2150, Accuracy: 96.14%
# Iteration 508/10000, Loss: 0.2148, Accuracy: 96.14%
# Iteration 509/10000, Loss: 0.2146, Accuracy: 96.14%
# Iteration 510/10000, Loss: 0.2144, Accuracy: 96.14%
# Iteration 511/10000, Loss: 0.2143, Accuracy: 96.14%
# Iteration 512/10000, Loss: 0.2141, Accuracy: 96.14%
# Iteration 513/10000, Loss: 0.2139, Accuracy: 96.14%
# Iteration 514/10000, Loss: 0.2137, Accuracy: 96.14%
# Iteration 515/10000, Loss: 0.2135, Accuracy: 96.14%
# Iteration 516/10000, Loss: 0.2133, Accuracy: 96.14%
# Iteration 517/10000, Loss: 0.2132, Accuracy: 96.14%
# Iteration 518/10000, Loss: 0.2130, Accuracy: 96.14%
# Iteration 519/10000, Loss: 0.2128, Accuracy: 96.14%
# Iteration 520/10000, Loss: 0.2126, Accuracy: 96.14%
# Iteration 521/10000, Loss: 0.2124, Accuracy: 96.14%
# Iteration 522/10000, Loss: 0.2123, Accuracy: 96.14%
# Iteration 523/10000, Loss: 0.2121, Accuracy: 96.14%
# Iteration 524/10000, Loss: 0.2119, Accuracy: 96.14%
# Iteration 525/10000, Loss: 0.2117, Accuracy: 96.14%
# Iteration 526/10000, Loss: 0.2115, Accuracy: 96.14%
# Iteration 527/10000, Loss: 0.2114, Accuracy: 96.14%
# Iteration 528/10000, Loss: 0.2112, Accuracy: 96.14%
# Iteration 529/10000, Loss: 0.2110, Accuracy: 96.14%
# Iteration 530/10000, Loss: 0.2108, Accuracy: 96.14%
# Iteration 531/10000, Loss: 0.2107, Accuracy: 96.14%
# Iteration 532/10000, Loss: 0.2105, Accuracy: 96.14%
# Iteration 533/10000, Loss: 0.2103, Accuracy: 96.14%
# Iteration 534/10000, Loss: 0.2101, Accuracy: 96.14%
# Iteration 535/10000, Loss: 0.2100, Accuracy: 96.14%
# Iteration 536/10000, Loss: 0.2098, Accuracy: 96.14%
# Iteration 537/10000, Loss: 0.2096, Accuracy: 96.14%
# Iteration 538/10000, Loss: 0.2095, Accuracy: 96.14%
# Iteration 539/10000, Loss: 0.2093, Accuracy: 96.14%
# Iteration 540/10000, Loss: 0.2091, Accuracy: 96.14%
# Iteration 541/10000, Loss: 0.2089, Accuracy: 96.14%
# Iteration 542/10000, Loss: 0.2088, Accuracy: 96.14%
# Iteration 543/10000, Loss: 0.2086, Accuracy: 96.14%
# Iteration 544/10000, Loss: 0.2084, Accuracy: 96.14%
# Iteration 545/10000, Loss: 0.2083, Accuracy: 96.14%
# Iteration 546/10000, Loss: 0.2081, Accuracy: 96.14%
# Iteration 547/10000, Loss: 0.2079, Accuracy: 96.14%
# Iteration 548/10000, Loss: 0.2078, Accuracy: 96.14%
# Iteration 549/10000, Loss: 0.2076, Accuracy: 96.14%
# Iteration 550/10000, Loss: 0.2075, Accuracy: 96.14%
# Iteration 551/10000, Loss: 0.2073, Accuracy: 96.14%
# Iteration 552/10000, Loss: 0.2071, Accuracy: 96.14%
# Iteration 553/10000, Loss: 0.2070, Accuracy: 96.14%
# Iteration 554/10000, Loss: 0.2068, Accuracy: 96.14%
# Iteration 555/10000, Loss: 0.2066, Accuracy: 96.14%
# Iteration 556/10000, Loss: 0.2065, Accuracy: 96.14%
# Iteration 557/10000, Loss: 0.2063, Accuracy: 96.14%
# Iteration 558/10000, Loss: 0.2062, Accuracy: 96.14%
# Iteration 559/10000, Loss: 0.2060, Accuracy: 96.14%
# Iteration 560/10000, Loss: 0.2058, Accuracy: 96.14%
# Iteration 561/10000, Loss: 0.2057, Accuracy: 96.14%
# Iteration 562/10000, Loss: 0.2055, Accuracy: 96.14%
# Iteration 563/10000, Loss: 0.2054, Accuracy: 96.14%
# Iteration 564/10000, Loss: 0.2052, Accuracy: 96.14%
# Iteration 565/10000, Loss: 0.2050, Accuracy: 96.14%
# Iteration 566/10000, Loss: 0.2049, Accuracy: 96.14%
# Iteration 567/10000, Loss: 0.2047, Accuracy: 96.14%
# Iteration 568/10000, Loss: 0.2046, Accuracy: 96.14%
# Iteration 569/10000, Loss: 0.2044, Accuracy: 96.14%
# Iteration 570/10000, Loss: 0.2043, Accuracy: 96.14%
# Iteration 571/10000, Loss: 0.2041, Accuracy: 96.14%
# Iteration 572/10000, Loss: 0.2039, Accuracy: 96.14%
# Iteration 573/10000, Loss: 0.2038, Accuracy: 96.14%
# Iteration 574/10000, Loss: 0.2036, Accuracy: 96.14%
# Iteration 575/10000, Loss: 0.2035, Accuracy: 96.14%
# Iteration 576/10000, Loss: 0.2033, Accuracy: 96.14%
# Iteration 577/10000, Loss: 0.2032, Accuracy: 96.14%
# Iteration 578/10000, Loss: 0.2030, Accuracy: 96.14%
# Iteration 579/10000, Loss: 0.2029, Accuracy: 96.14%
# Iteration 580/10000, Loss: 0.2027, Accuracy: 96.14%
# Iteration 581/10000, Loss: 0.2026, Accuracy: 96.14%
# Iteration 582/10000, Loss: 0.2024, Accuracy: 96.14%
# Iteration 583/10000, Loss: 0.2023, Accuracy: 96.14%
# Iteration 584/10000, Loss: 0.2021, Accuracy: 96.14%
# Iteration 585/10000, Loss: 0.2020, Accuracy: 96.14%
# Iteration 586/10000, Loss: 0.2018, Accuracy: 96.14%
# Iteration 587/10000, Loss: 0.2017, Accuracy: 96.14%
# Iteration 588/10000, Loss: 0.2015, Accuracy: 96.14%
# Iteration 589/10000, Loss: 0.2014, Accuracy: 96.14%
# Iteration 590/10000, Loss: 0.2012, Accuracy: 96.14%
# Iteration 591/10000, Loss: 0.2011, Accuracy: 96.14%
# Iteration 592/10000, Loss: 0.2009, Accuracy: 96.14%
# Iteration 593/10000, Loss: 0.2008, Accuracy: 96.14%
# Iteration 594/10000, Loss: 0.2007, Accuracy: 96.14%
# Iteration 595/10000, Loss: 0.2005, Accuracy: 96.14%
# Iteration 596/10000, Loss: 0.2004, Accuracy: 96.14%
# Iteration 597/10000, Loss: 0.2002, Accuracy: 96.14%
# Iteration 598/10000, Loss: 0.2001, Accuracy: 96.14%
# Iteration 599/10000, Loss: 0.1999, Accuracy: 96.14%
# Iteration 600/10000, Loss: 0.1998, Accuracy: 96.14%
# Iteration 601/10000, Loss: 0.1997, Accuracy: 96.14%
# Iteration 602/10000, Loss: 0.1995, Accuracy: 96.14%
# Iteration 603/10000, Loss: 0.1994, Accuracy: 96.14%
# Iteration 604/10000, Loss: 0.1992, Accuracy: 96.14%
# Iteration 605/10000, Loss: 0.1991, Accuracy: 96.14%
# Iteration 606/10000, Loss: 0.1989, Accuracy: 96.14%
# Iteration 607/10000, Loss: 0.1988, Accuracy: 96.14%
# Iteration 608/10000, Loss: 0.1987, Accuracy: 96.14%
# Iteration 609/10000, Loss: 0.1985, Accuracy: 96.14%
# Iteration 610/10000, Loss: 0.1984, Accuracy: 96.14%
# Iteration 611/10000, Loss: 0.1983, Accuracy: 96.14%
# Iteration 612/10000, Loss: 0.1981, Accuracy: 96.14%
# Iteration 613/10000, Loss: 0.1980, Accuracy: 96.14%
# Iteration 614/10000, Loss: 0.1978, Accuracy: 96.14%
# Iteration 615/10000, Loss: 0.1977, Accuracy: 96.14%
# Iteration 616/10000, Loss: 0.1976, Accuracy: 96.14%
# Iteration 617/10000, Loss: 0.1974, Accuracy: 96.14%
# Iteration 618/10000, Loss: 0.1973, Accuracy: 96.14%
# Iteration 619/10000, Loss: 0.1972, Accuracy: 96.14%
# Iteration 620/10000, Loss: 0.1970, Accuracy: 96.14%
# Iteration 621/10000, Loss: 0.1969, Accuracy: 96.14%
# Iteration 622/10000, Loss: 0.1968, Accuracy: 96.14%
# Iteration 623/10000, Loss: 0.1966, Accuracy: 96.14%
# Iteration 624/10000, Loss: 0.1965, Accuracy: 96.14%
# Iteration 625/10000, Loss: 0.1964, Accuracy: 96.14%
# Iteration 626/10000, Loss: 0.1962, Accuracy: 96.14%
# Iteration 627/10000, Loss: 0.1961, Accuracy: 96.14%
# Iteration 628/10000, Loss: 0.1960, Accuracy: 96.14%
# Iteration 629/10000, Loss: 0.1958, Accuracy: 96.14%
# Iteration 630/10000, Loss: 0.1957, Accuracy: 96.14%
# Iteration 631/10000, Loss: 0.1956, Accuracy: 96.14%
# Iteration 632/10000, Loss: 0.1954, Accuracy: 96.14%
# Iteration 633/10000, Loss: 0.1953, Accuracy: 96.14%
# Iteration 634/10000, Loss: 0.1952, Accuracy: 96.14%
# Iteration 635/10000, Loss: 0.1950, Accuracy: 96.14%
# Iteration 636/10000, Loss: 0.1949, Accuracy: 96.14%
# Iteration 637/10000, Loss: 0.1948, Accuracy: 96.14%
# Iteration 638/10000, Loss: 0.1946, Accuracy: 96.14%
# Iteration 639/10000, Loss: 0.1945, Accuracy: 96.14%
# Iteration 640/10000, Loss: 0.1944, Accuracy: 96.14%
# Iteration 641/10000, Loss: 0.1943, Accuracy: 96.14%
# Iteration 642/10000, Loss: 0.1941, Accuracy: 96.14%
# Iteration 643/10000, Loss: 0.1940, Accuracy: 96.14%
# Iteration 644/10000, Loss: 0.1939, Accuracy: 96.14%
# Iteration 645/10000, Loss: 0.1938, Accuracy: 96.14%
# Iteration 646/10000, Loss: 0.1936, Accuracy: 96.14%
# Iteration 647/10000, Loss: 0.1935, Accuracy: 96.14%
# Iteration 648/10000, Loss: 0.1934, Accuracy: 96.14%
# Iteration 649/10000, Loss: 0.1933, Accuracy: 96.14%
# Iteration 650/10000, Loss: 0.1931, Accuracy: 96.14%
# Iteration 651/10000, Loss: 0.1930, Accuracy: 96.14%
# Iteration 652/10000, Loss: 0.1929, Accuracy: 96.14%
# Iteration 653/10000, Loss: 0.1928, Accuracy: 96.14%
# Iteration 654/10000, Loss: 0.1926, Accuracy: 96.14%
# Iteration 655/10000, Loss: 0.1925, Accuracy: 96.14%
# Iteration 656/10000, Loss: 0.1924, Accuracy: 96.14%
# Iteration 657/10000, Loss: 0.1923, Accuracy: 96.14%
# Iteration 658/10000, Loss: 0.1921, Accuracy: 96.14%
# Iteration 659/10000, Loss: 0.1920, Accuracy: 96.14%
# Iteration 660/10000, Loss: 0.1919, Accuracy: 96.14%
# Iteration 661/10000, Loss: 0.1918, Accuracy: 96.14%
# Iteration 662/10000, Loss: 0.1917, Accuracy: 96.14%
# Iteration 663/10000, Loss: 0.1915, Accuracy: 96.14%
# Iteration 664/10000, Loss: 0.1914, Accuracy: 96.14%
# Iteration 665/10000, Loss: 0.1913, Accuracy: 96.14%
# Iteration 666/10000, Loss: 0.1912, Accuracy: 96.14%
# Iteration 667/10000, Loss: 0.1910, Accuracy: 96.14%
# Iteration 668/10000, Loss: 0.1909, Accuracy: 96.14%
# Iteration 669/10000, Loss: 0.1908, Accuracy: 96.14%
# Iteration 670/10000, Loss: 0.1907, Accuracy: 96.14%
# Iteration 671/10000, Loss: 0.1906, Accuracy: 96.14%
# Iteration 672/10000, Loss: 0.1905, Accuracy: 96.14%
# Iteration 673/10000, Loss: 0.1903, Accuracy: 96.14%
# Iteration 674/10000, Loss: 0.1902, Accuracy: 96.14%
# Iteration 675/10000, Loss: 0.1901, Accuracy: 96.14%
# Iteration 676/10000, Loss: 0.1900, Accuracy: 96.14%
# Iteration 677/10000, Loss: 0.1899, Accuracy: 96.14%
# Iteration 678/10000, Loss: 0.1898, Accuracy: 96.14%
# Iteration 679/10000, Loss: 0.1896, Accuracy: 96.14%
# Iteration 680/10000, Loss: 0.1895, Accuracy: 96.14%
# Iteration 681/10000, Loss: 0.1894, Accuracy: 96.14%
# Iteration 682/10000, Loss: 0.1893, Accuracy: 96.14%
# Iteration 683/10000, Loss: 0.1892, Accuracy: 96.14%
# Iteration 684/10000, Loss: 0.1891, Accuracy: 96.14%
# Iteration 685/10000, Loss: 0.1889, Accuracy: 96.14%
# Iteration 686/10000, Loss: 0.1888, Accuracy: 96.14%
# Iteration 687/10000, Loss: 0.1887, Accuracy: 96.14%
# Iteration 688/10000, Loss: 0.1886, Accuracy: 96.14%
# Iteration 689/10000, Loss: 0.1885, Accuracy: 96.14%
# Iteration 690/10000, Loss: 0.1884, Accuracy: 96.14%
# Iteration 691/10000, Loss: 0.1883, Accuracy: 96.14%
# Iteration 692/10000, Loss: 0.1882, Accuracy: 96.14%
# Iteration 693/10000, Loss: 0.1880, Accuracy: 96.14%
# Iteration 694/10000, Loss: 0.1879, Accuracy: 96.14%
# Iteration 695/10000, Loss: 0.1878, Accuracy: 96.14%
# Iteration 696/10000, Loss: 0.1877, Accuracy: 96.14%
# Iteration 697/10000, Loss: 0.1876, Accuracy: 96.14%
# Iteration 698/10000, Loss: 0.1875, Accuracy: 96.14%
# Iteration 699/10000, Loss: 0.1874, Accuracy: 96.14%
# Iteration 700/10000, Loss: 0.1873, Accuracy: 96.14%
# Iteration 701/10000, Loss: 0.1872, Accuracy: 96.14%
# Iteration 702/10000, Loss: 0.1870, Accuracy: 96.14%
# Iteration 703/10000, Loss: 0.1869, Accuracy: 96.14%
# Iteration 704/10000, Loss: 0.1868, Accuracy: 96.14%
# Iteration 705/10000, Loss: 0.1867, Accuracy: 96.14%
# Iteration 706/10000, Loss: 0.1866, Accuracy: 96.19%
# Iteration 707/10000, Loss: 0.1865, Accuracy: 96.19%
# Iteration 708/10000, Loss: 0.1864, Accuracy: 96.19%
# Iteration 709/10000, Loss: 0.1863, Accuracy: 96.19%
# Iteration 710/10000, Loss: 0.1862, Accuracy: 96.19%
# Iteration 711/10000, Loss: 0.1861, Accuracy: 96.19%
# Iteration 712/10000, Loss: 0.1860, Accuracy: 96.19%
# Iteration 713/10000, Loss: 0.1858, Accuracy: 96.19%
# Iteration 714/10000, Loss: 0.1857, Accuracy: 96.19%
# Iteration 715/10000, Loss: 0.1856, Accuracy: 96.19%
# Iteration 716/10000, Loss: 0.1855, Accuracy: 96.19%
# Iteration 717/10000, Loss: 0.1854, Accuracy: 96.19%
# Iteration 718/10000, Loss: 0.1853, Accuracy: 96.19%
# Iteration 719/10000, Loss: 0.1852, Accuracy: 96.19%
# Iteration 720/10000, Loss: 0.1851, Accuracy: 96.19%
# Iteration 721/10000, Loss: 0.1850, Accuracy: 96.19%
# Iteration 722/10000, Loss: 0.1849, Accuracy: 96.19%
# Iteration 723/10000, Loss: 0.1848, Accuracy: 96.19%
# Iteration 724/10000, Loss: 0.1847, Accuracy: 96.19%
# Iteration 725/10000, Loss: 0.1846, Accuracy: 96.19%
# Iteration 726/10000, Loss: 0.1845, Accuracy: 96.19%
# Iteration 727/10000, Loss: 0.1844, Accuracy: 96.19%
# Iteration 728/10000, Loss: 0.1843, Accuracy: 96.19%
# Iteration 729/10000, Loss: 0.1842, Accuracy: 96.19%
# Iteration 730/10000, Loss: 0.1841, Accuracy: 96.19%
# Iteration 731/10000, Loss: 0.1840, Accuracy: 96.19%
# Iteration 732/10000, Loss: 0.1839, Accuracy: 96.19%
# Iteration 733/10000, Loss: 0.1838, Accuracy: 96.19%
# Iteration 734/10000, Loss: 0.1837, Accuracy: 96.19%
# Iteration 735/10000, Loss: 0.1836, Accuracy: 96.19%
# Iteration 736/10000, Loss: 0.1835, Accuracy: 96.19%
# Iteration 737/10000, Loss: 0.1834, Accuracy: 96.19%
# Iteration 738/10000, Loss: 0.1833, Accuracy: 96.19%
# Iteration 739/10000, Loss: 0.1832, Accuracy: 96.19%
# Iteration 740/10000, Loss: 0.1831, Accuracy: 96.19%
# Iteration 741/10000, Loss: 0.1830, Accuracy: 96.19%
# Iteration 742/10000, Loss: 0.1829, Accuracy: 96.19%
# Iteration 743/10000, Loss: 0.1828, Accuracy: 96.19%
# Iteration 744/10000, Loss: 0.1827, Accuracy: 96.19%
# Iteration 745/10000, Loss: 0.1826, Accuracy: 96.19%
# Iteration 746/10000, Loss: 0.1825, Accuracy: 96.19%
# Iteration 747/10000, Loss: 0.1824, Accuracy: 96.19%
# Iteration 748/10000, Loss: 0.1823, Accuracy: 96.19%
# Iteration 749/10000, Loss: 0.1822, Accuracy: 96.19%
# Iteration 750/10000, Loss: 0.1821, Accuracy: 96.19%
# Iteration 751/10000, Loss: 0.1820, Accuracy: 96.19%
# Iteration 752/10000, Loss: 0.1819, Accuracy: 96.19%
# Iteration 753/10000, Loss: 0.1818, Accuracy: 96.19%
# Iteration 754/10000, Loss: 0.1817, Accuracy: 96.19%
# Iteration 755/10000, Loss: 0.1816, Accuracy: 96.19%
# Iteration 756/10000, Loss: 0.1815, Accuracy: 96.19%
# Iteration 757/10000, Loss: 0.1814, Accuracy: 96.19%
# Iteration 758/10000, Loss: 0.1813, Accuracy: 96.19%
# Iteration 759/10000, Loss: 0.1812, Accuracy: 96.19%
# Iteration 760/10000, Loss: 0.1811, Accuracy: 96.19%
# Iteration 761/10000, Loss: 0.1810, Accuracy: 96.19%
# Iteration 762/10000, Loss: 0.1809, Accuracy: 96.19%
# Iteration 763/10000, Loss: 0.1808, Accuracy: 96.19%
# Iteration 764/10000, Loss: 0.1807, Accuracy: 96.19%
# Iteration 765/10000, Loss: 0.1806, Accuracy: 96.19%
# Iteration 766/10000, Loss: 0.1805, Accuracy: 96.19%
# Iteration 767/10000, Loss: 0.1804, Accuracy: 96.19%
# Iteration 768/10000, Loss: 0.1803, Accuracy: 96.19%
# Iteration 769/10000, Loss: 0.1802, Accuracy: 96.19%
# Iteration 770/10000, Loss: 0.1801, Accuracy: 96.19%
# Iteration 771/10000, Loss: 0.1800, Accuracy: 96.19%
# Iteration 772/10000, Loss: 0.1800, Accuracy: 96.19%
# Iteration 773/10000, Loss: 0.1799, Accuracy: 96.19%
# Iteration 774/10000, Loss: 0.1798, Accuracy: 96.19%
# Iteration 775/10000, Loss: 0.1797, Accuracy: 96.19%
# Iteration 776/10000, Loss: 0.1796, Accuracy: 96.19%
# Iteration 777/10000, Loss: 0.1795, Accuracy: 96.19%
# Iteration 778/10000, Loss: 0.1794, Accuracy: 96.19%
# Iteration 779/10000, Loss: 0.1793, Accuracy: 96.19%
# Iteration 780/10000, Loss: 0.1792, Accuracy: 96.19%
# Iteration 781/10000, Loss: 0.1791, Accuracy: 96.19%
# Iteration 782/10000, Loss: 0.1790, Accuracy: 96.19%
# Iteration 783/10000, Loss: 0.1789, Accuracy: 96.19%
# Iteration 784/10000, Loss: 0.1788, Accuracy: 96.19%
# Iteration 785/10000, Loss: 0.1788, Accuracy: 96.19%
# Iteration 786/10000, Loss: 0.1787, Accuracy: 96.19%
# Iteration 787/10000, Loss: 0.1786, Accuracy: 96.19%
# Iteration 788/10000, Loss: 0.1785, Accuracy: 96.19%
# Iteration 789/10000, Loss: 0.1784, Accuracy: 96.19%
# Iteration 790/10000, Loss: 0.1783, Accuracy: 96.19%
# Iteration 791/10000, Loss: 0.1782, Accuracy: 96.19%
# Iteration 792/10000, Loss: 0.1781, Accuracy: 96.19%
# Iteration 793/10000, Loss: 0.1780, Accuracy: 96.19%
# Iteration 794/10000, Loss: 0.1779, Accuracy: 96.19%
# Iteration 795/10000, Loss: 0.1779, Accuracy: 96.19%
# Iteration 796/10000, Loss: 0.1778, Accuracy: 96.19%
# Iteration 797/10000, Loss: 0.1777, Accuracy: 96.19%
# Iteration 798/10000, Loss: 0.1776, Accuracy: 96.19%
# Iteration 799/10000, Loss: 0.1775, Accuracy: 96.19%
# Iteration 800/10000, Loss: 0.1774, Accuracy: 96.19%
# Iteration 801/10000, Loss: 0.1773, Accuracy: 96.19%
# Iteration 802/10000, Loss: 0.1772, Accuracy: 96.19%
# Iteration 803/10000, Loss: 0.1771, Accuracy: 96.19%
# Iteration 804/10000, Loss: 0.1771, Accuracy: 96.19%
# Iteration 805/10000, Loss: 0.1770, Accuracy: 96.19%
# Iteration 806/10000, Loss: 0.1769, Accuracy: 96.19%
# Iteration 807/10000, Loss: 0.1768, Accuracy: 96.19%
# Iteration 808/10000, Loss: 0.1767, Accuracy: 96.19%
# Iteration 809/10000, Loss: 0.1766, Accuracy: 96.19%
# Iteration 810/10000, Loss: 0.1765, Accuracy: 96.19%
# Iteration 811/10000, Loss: 0.1765, Accuracy: 96.19%
# Iteration 812/10000, Loss: 0.1764, Accuracy: 96.19%
# Iteration 813/10000, Loss: 0.1763, Accuracy: 96.19%
# Iteration 814/10000, Loss: 0.1762, Accuracy: 96.19%
# Iteration 815/10000, Loss: 0.1761, Accuracy: 96.19%
# Iteration 816/10000, Loss: 0.1760, Accuracy: 96.19%
# Iteration 817/10000, Loss: 0.1759, Accuracy: 96.19%
# Iteration 818/10000, Loss: 0.1759, Accuracy: 96.19%
# Iteration 819/10000, Loss: 0.1758, Accuracy: 96.19%
# Iteration 820/10000, Loss: 0.1757, Accuracy: 96.19%
# Iteration 821/10000, Loss: 0.1756, Accuracy: 96.19%
# Iteration 822/10000, Loss: 0.1755, Accuracy: 96.19%
# Iteration 823/10000, Loss: 0.1754, Accuracy: 96.19%
# Iteration 824/10000, Loss: 0.1754, Accuracy: 96.19%
# Iteration 825/10000, Loss: 0.1753, Accuracy: 96.19%
# Iteration 826/10000, Loss: 0.1752, Accuracy: 96.19%
# Iteration 827/10000, Loss: 0.1751, Accuracy: 96.19%
# Iteration 828/10000, Loss: 0.1750, Accuracy: 96.19%
# Iteration 829/10000, Loss: 0.1749, Accuracy: 96.19%
# Iteration 830/10000, Loss: 0.1749, Accuracy: 96.19%
# Iteration 831/10000, Loss: 0.1748, Accuracy: 96.19%
# Iteration 832/10000, Loss: 0.1747, Accuracy: 96.19%
# Iteration 833/10000, Loss: 0.1746, Accuracy: 96.19%
# Iteration 834/10000, Loss: 0.1745, Accuracy: 96.19%
# Iteration 835/10000, Loss: 0.1744, Accuracy: 96.19%
# Iteration 836/10000, Loss: 0.1744, Accuracy: 96.19%
# Iteration 837/10000, Loss: 0.1743, Accuracy: 96.19%
# Iteration 838/10000, Loss: 0.1742, Accuracy: 96.19%
# Iteration 839/10000, Loss: 0.1741, Accuracy: 96.19%
# Iteration 840/10000, Loss: 0.1740, Accuracy: 96.19%
# Iteration 841/10000, Loss: 0.1740, Accuracy: 96.19%
# Iteration 842/10000, Loss: 0.1739, Accuracy: 96.19%
# Iteration 843/10000, Loss: 0.1738, Accuracy: 96.19%
# Iteration 844/10000, Loss: 0.1737, Accuracy: 96.19%
# Iteration 845/10000, Loss: 0.1736, Accuracy: 96.19%
# Iteration 846/10000, Loss: 0.1736, Accuracy: 96.19%
# Iteration 847/10000, Loss: 0.1735, Accuracy: 96.19%
# Iteration 848/10000, Loss: 0.1734, Accuracy: 96.19%
# Iteration 849/10000, Loss: 0.1733, Accuracy: 96.19%
# Iteration 850/10000, Loss: 0.1732, Accuracy: 96.19%
# Iteration 851/10000, Loss: 0.1732, Accuracy: 96.19%
# Iteration 852/10000, Loss: 0.1731, Accuracy: 96.19%
# Iteration 853/10000, Loss: 0.1730, Accuracy: 96.19%
# Iteration 854/10000, Loss: 0.1729, Accuracy: 96.19%
# Iteration 855/10000, Loss: 0.1728, Accuracy: 96.19%
# Iteration 856/10000, Loss: 0.1728, Accuracy: 96.19%
# Iteration 857/10000, Loss: 0.1727, Accuracy: 96.19%
# Iteration 858/10000, Loss: 0.1726, Accuracy: 96.19%
# Iteration 859/10000, Loss: 0.1725, Accuracy: 96.19%
# Iteration 860/10000, Loss: 0.1724, Accuracy: 96.19%
# Iteration 861/10000, Loss: 0.1724, Accuracy: 96.19%
# Iteration 862/10000, Loss: 0.1723, Accuracy: 96.19%
# Iteration 863/10000, Loss: 0.1722, Accuracy: 96.19%
# Iteration 864/10000, Loss: 0.1721, Accuracy: 96.19%
# Iteration 865/10000, Loss: 0.1721, Accuracy: 96.19%
# Iteration 866/10000, Loss: 0.1720, Accuracy: 96.19%
# Iteration 867/10000, Loss: 0.1719, Accuracy: 96.19%
# Iteration 868/10000, Loss: 0.1718, Accuracy: 96.19%
# Iteration 869/10000, Loss: 0.1718, Accuracy: 96.19%
# Iteration 870/10000, Loss: 0.1717, Accuracy: 96.19%
# Iteration 871/10000, Loss: 0.1716, Accuracy: 96.19%
# Iteration 872/10000, Loss: 0.1715, Accuracy: 96.19%
# Iteration 873/10000, Loss: 0.1715, Accuracy: 96.19%
# Iteration 874/10000, Loss: 0.1714, Accuracy: 96.19%
# Iteration 875/10000, Loss: 0.1713, Accuracy: 96.19%
# Iteration 876/10000, Loss: 0.1712, Accuracy: 96.19%
# Iteration 877/10000, Loss: 0.1711, Accuracy: 96.19%
# Iteration 878/10000, Loss: 0.1711, Accuracy: 96.19%
# Iteration 879/10000, Loss: 0.1710, Accuracy: 96.19%
# Iteration 880/10000, Loss: 0.1709, Accuracy: 96.19%
# Iteration 881/10000, Loss: 0.1709, Accuracy: 96.19%
# Iteration 882/10000, Loss: 0.1708, Accuracy: 96.19%
# Iteration 883/10000, Loss: 0.1707, Accuracy: 96.19%
# Iteration 884/10000, Loss: 0.1706, Accuracy: 96.19%
# Iteration 885/10000, Loss: 0.1706, Accuracy: 96.19%
# Iteration 886/10000, Loss: 0.1705, Accuracy: 96.19%
# Iteration 887/10000, Loss: 0.1704, Accuracy: 96.19%
# Iteration 888/10000, Loss: 0.1703, Accuracy: 96.19%
# Iteration 889/10000, Loss: 0.1703, Accuracy: 96.19%
# Iteration 890/10000, Loss: 0.1702, Accuracy: 96.19%
# Iteration 891/10000, Loss: 0.1701, Accuracy: 96.19%
# Iteration 892/10000, Loss: 0.1700, Accuracy: 96.19%
# Iteration 893/10000, Loss: 0.1700, Accuracy: 96.19%
# Iteration 894/10000, Loss: 0.1699, Accuracy: 96.19%
# Iteration 895/10000, Loss: 0.1698, Accuracy: 96.19%
# Iteration 896/10000, Loss: 0.1697, Accuracy: 96.19%
# Iteration 897/10000, Loss: 0.1697, Accuracy: 96.19%
# Iteration 898/10000, Loss: 0.1696, Accuracy: 96.19%
# Iteration 899/10000, Loss: 0.1695, Accuracy: 96.19%
# Iteration 900/10000, Loss: 0.1695, Accuracy: 96.19%
# Iteration 901/10000, Loss: 0.1694, Accuracy: 96.19%
# Iteration 902/10000, Loss: 0.1693, Accuracy: 96.19%
# Iteration 903/10000, Loss: 0.1692, Accuracy: 96.19%
# Iteration 904/10000, Loss: 0.1692, Accuracy: 96.19%
# Iteration 905/10000, Loss: 0.1691, Accuracy: 96.19%
# Iteration 906/10000, Loss: 0.1690, Accuracy: 96.19%
# Iteration 907/10000, Loss: 0.1690, Accuracy: 96.19%
# Iteration 908/10000, Loss: 0.1689, Accuracy: 96.14%
# Iteration 909/10000, Loss: 0.1688, Accuracy: 96.14%
# Iteration 910/10000, Loss: 0.1687, Accuracy: 96.14%
# Iteration 911/10000, Loss: 0.1687, Accuracy: 96.19%
# Iteration 912/10000, Loss: 0.1686, Accuracy: 96.19%
# Iteration 913/10000, Loss: 0.1685, Accuracy: 96.19%
# Iteration 914/10000, Loss: 0.1685, Accuracy: 96.19%
# Iteration 915/10000, Loss: 0.1684, Accuracy: 96.19%
# Iteration 916/10000, Loss: 0.1683, Accuracy: 96.19%
# Iteration 917/10000, Loss: 0.1683, Accuracy: 96.19%
# Iteration 918/10000, Loss: 0.1682, Accuracy: 96.19%
# Iteration 919/10000, Loss: 0.1681, Accuracy: 96.19%
# Iteration 920/10000, Loss: 0.1680, Accuracy: 96.19%
# Iteration 921/10000, Loss: 0.1680, Accuracy: 96.19%
# Iteration 922/10000, Loss: 0.1679, Accuracy: 96.19%
# Iteration 923/10000, Loss: 0.1678, Accuracy: 96.19%
# Iteration 924/10000, Loss: 0.1678, Accuracy: 96.19%
# Iteration 925/10000, Loss: 0.1677, Accuracy: 96.19%
# ...
# Iteration 9700/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9701/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9702/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9703/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9704/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9705/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9706/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9707/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9708/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9709/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9710/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9711/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9712/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9713/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9714/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9715/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9716/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9717/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9718/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9719/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9720/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9721/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9722/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9723/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9724/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9725/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9726/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9727/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9728/10000, Loss: 0.1023, Accuracy: 96.34%
# Iteration 9729/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9730/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9731/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9732/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9733/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9734/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9735/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9736/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9737/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9738/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9739/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9740/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9741/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9742/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9743/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9744/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9745/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9746/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9747/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9748/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9749/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9750/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9751/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9752/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9753/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9754/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9755/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9756/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9757/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9758/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9759/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9760/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9761/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9762/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9763/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9764/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9765/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9766/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9767/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9768/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9769/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9770/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9771/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9772/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9773/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9774/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9775/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9776/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9777/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9778/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9779/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9780/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9781/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9782/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9783/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9784/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9785/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9786/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9787/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9788/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9789/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9790/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9791/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9792/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9793/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9794/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9795/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9796/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9797/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9798/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9799/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9800/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9801/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9802/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9803/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9804/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9805/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9806/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9807/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9808/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9809/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9810/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9811/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9812/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9813/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9814/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9815/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9816/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9817/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9818/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9819/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9820/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9821/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9822/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9823/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9824/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9825/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9826/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9827/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9828/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9829/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9830/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9831/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9832/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9833/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9834/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9835/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9836/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9837/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9838/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9839/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9840/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9841/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9842/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9843/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9844/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9845/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9846/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9847/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9848/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9849/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9850/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9851/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9852/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9853/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9854/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9855/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9856/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9857/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9858/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9859/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9860/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9861/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9862/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9863/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9864/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9865/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9866/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9867/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9868/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9869/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9870/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9871/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9872/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9873/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9874/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9875/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9876/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9877/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9878/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9879/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9880/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9881/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9882/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9883/10000, Loss: 0.1022, Accuracy: 96.34%
# Iteration 9884/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9885/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9886/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9887/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9888/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9889/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9890/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9891/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9892/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9893/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9894/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9895/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9896/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9897/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9898/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9899/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9900/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9901/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9902/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9903/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9904/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9905/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9906/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9907/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9908/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9909/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9910/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9911/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9912/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9913/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9914/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9915/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9916/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9917/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9918/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9919/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9920/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9921/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9922/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9923/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9924/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9925/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9926/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9927/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9928/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9929/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9930/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9931/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9932/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9933/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9934/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9935/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9936/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9937/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9938/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9939/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9940/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9941/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9942/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9943/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9944/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9945/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9946/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9947/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9948/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9949/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9950/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9951/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9952/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9953/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9954/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9955/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9956/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9957/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9958/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9959/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9960/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9961/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9962/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9963/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9964/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9965/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9966/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9967/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9968/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9969/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9970/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9971/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9972/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9973/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9974/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9975/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9976/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9977/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9978/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9979/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9980/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9981/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9982/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9983/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9984/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9985/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9986/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9987/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9988/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9989/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9990/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9991/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9992/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9993/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9994/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9995/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9996/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9997/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9998/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 9999/10000, Loss: 0.1021, Accuracy: 96.34%
# Iteration 10000/10000, Loss: 0.1021, Accuracy: 96.34%

# %%
# Visualize decision boundary after training
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w[0, 0] * xx + w[0, 1] * yy + b - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
plt.title('Decision Boundary after Training')
# Out:
# Text(0.5, 1.0, 'Decision Boundary after Training')

# %% [markdown]
# ## 5. Evaluate Model with a New Dataset
# Let's generate a similar dataset using [make_blobs](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs) as used in the beginning of this practice.
# Make predictions and evaluate model with this newly generated dataset.

# %%
# Accuracy on training data
X_raw, y_raw = make_blobs(n_samples=512, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0,)
features_test = X_raw / X_raw.max(axis=0)  # Scale features to [-1, 1]
labels_test = y_raw.reshape(-1, 1)  # Reshape labels to be a column vector

# Visualize test data
plt.scatter(
    features_test[:, 0], 
    features_test[:, 1], 
    s=5*np.ones(labels_test.size), 
    c=labels_test, 
    cmap='managua'  # color map
)
# Visualize decision boundary on test data
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['orange', 'cyan'], alpha=0.25)
plt.title('Decision Boundary on Test Data')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on Test Data')

# %% [markdown]
# Besides accuracy, a handful of metrics are useful to evaluate how sensitive/precise/balance the model is.
# A confusion matrix is a handy tool to visualize these metrics.

# %%
# Confusion Matrix for Test Data
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

preds_test = forward(features_test, w, b)
cm_test = confusion_matrix(labels_test, (preds_test >= 0.5).astype(int))
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=[0, 1])
disp_test.plot(cmap='PuRd')
plt.title('Confusion Matrix - Test Data')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix - Test Data')

# %% [markdown]
# ### <font color=#582C83>(25%) Exercise 6: Classification Metrics</font>
# According to your confusion matrix on the **test dataset**. Please calculate the following metrics and write your answers below.
# > Let $0$ be negative, and $1$ be positive.
#
# - `Accuracy`=?
# - `Recall`=?
# - `Precision`=?
# - `F1 Score`=?
#
# <font color=#582C83>Assume the model is used by the quality control department in a factory to detect defective products (class 1).
# Please briefly state (2 sentences maximum) why or why not this model is good for this job.</font>
# > Please write down your answer below.

# %% [markdown]
# ### Accuracy = 0.9883
# ### Recall = 0.9922
# ### Precision = 0.9845
# ### F1 Score = 0.9883

# %% [markdown]
# # Congratulations! You have finished this assignment!
